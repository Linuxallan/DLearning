# %% [markdown]
# # Funcion de error personalizada con Tensorflow

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# ## Huber loss

# %% [markdown]
# La función de pérdida de Huber describe la pena incurrida por un procedimiento de estimación f. Huber (1964) define la función de pérdida de forma fragmentada por:
#
# $$ {\displaystyle L_{\delta }(y,h(x))={\begin{cases}{\frac {1}{2}}(y-h(x))^{2} \hspace{1.5cm} {\textrm {for}}|y-h(x)|\leq \delta ,\\\delta \,|y-h(x)|-{\frac {1}{2}}\delta ^{2} \hspace{5mm} {\textrm {otherwise.}}\end{cases}}}$$
#
# Más información: https://en.wikipedia.org/wiki/Huber_loss

# %%
# Función que genera al función de pérdida de Huber
def create_huber(threshold=1.0):
    def huber_fn(y_true, y_pred):
        error = y_true - y_pred
        is_small_error = tf.abs(error) <= threshold
        squared_loss = tf.square(error) / 2
        linear_loss  = threshold * tf.abs(error) - threshold**2 / 2
        return tf.where(is_small_error, squared_loss, linear_loss)
    return huber_fn

# %% [markdown]
# A continuación se representa gráficamente la función de pérdida de Huber en función del threshold seleccionado

# %%
# El valor más habitual para la función de pérdida de Huber es 1.0
huber_fn = create_huber(1.0)

# %%
# Representación gráfica de la función de pérdida de Huber
from matplotlib import pyplot as plt
import numpy as np

plt.figure(figsize=(10, 5.5))

# Selecciona 200 valores entre el rango [-4, 4]
z = np.linspace(-4, 4, 200)

plt.plot(z, huber_fn(0, z), "b-", linewidth=2, label="huber($z$)")

plt.gca().axvline(x=0, color='k')
plt.axis([-4, 4, 0, 4])
plt.grid(True)
plt.xlabel("$z$")
plt.ylabel("$huber\_loss(0, z)$")
plt.legend(fontsize=14)
plt.title("Huber loss", fontsize=14)
plt.show()

# %% [markdown]
# ## Entrenando una Red Neuronal Artificial con la nueva función de error

# %% [markdown]
# A continuación se pone en práctica la función de error definida en el apartado anterior en un ejercicio práctico. Para ello, se va a utilizar el caso de uso práctico de predicción del precio de una vivienda presentado en la sección de introducción a Keras

# %% [markdown]
# ### Importando el conjunto de datos

# %%
from tensorflow.keras import datasets

# %%
boston_housing = datasets.boston_housing

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# 65536/57026 [==================================] - 0s 0us/step

# %%
import pandas as pd

features = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

df_train = pd.DataFrame(np.column_stack([X_train, y_train]), columns=features)
df_train.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 5  0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# 6  9.18702   0.0  18.10   0.0  0.700  5.536  100.0  1.5804  24.0  666.0
# 7  4.09740   0.0  19.58   0.0  0.871  5.468  100.0  1.4118   5.0  403.0
# 8  2.15505   0.0  19.58   0.0  0.871  5.628  100.0  1.5166   5.0  403.0
# 9  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394   4.0  437.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     21.0  396.90  18.72  15.2
# 1     14.7  395.38   3.11  42.3
# 2     20.2  375.52   3.26  50.0
# 3     20.2  396.90   8.01  21.1
# 4     20.2  391.43  14.65  17.7
# 5     19.6  391.13  11.74  18.5
# 6     20.2  396.90  23.60  11.3
# 7     14.7  396.90  26.42  15.6
# 8     14.7  169.27  16.65  15.6
# 9     21.2  396.90  34.41  14.4

# %% [markdown]
# ### División del conjunto de datos

# %%
from sklearn.model_selection import train_test_split

X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %% [markdown]
# ### Escalando el conjunto de datos

# %%
# Normalizacion de las variables
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_train_prep = scaler.fit_transform(X_train)
X_val_prep = scaler.transform(X_val)
X_test_prep = scaler.transform(X_test)

# %% [markdown]
# ### Definicion de la arquitectura de la Red Neuronal Artificial

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
network = models.Sequential()

network.add(layers.Dense(30, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(10, activation='relu'))
# No tiene funcion de activacion por que el problema es de Regresion.
network.add(layers.Dense(1))

# %%
network.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 30)                420
#
#  dense_4 (Dense)             (None, 10)                310
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 741
# Trainable params: 741
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenamiento de la Red Neuronal Artificial

# %% [markdown]
# #### Función de error utilizada en el ejercicio práctico de introducción a Keras

# %% [markdown]
# A continuación se muestra la representación gráfica de la evaluación de los valores resultantes de la función de error **_mean_squared_error_** durante el proceso de entrenamiento.

# %%
network.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mae']
               )

# %%
history = network.fit(X_train_prep, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 3s 16ms/step - loss: 609.2278 - mae: 22.8452 - val_loss: 546.4022 - val_mae: 21.9347
# Epoch 2/50
# 13/13 [==============================] - 0s 4ms/step - loss: 596.8802 - mae: 22.5923 - val_loss: 537.1177 - val_mae: 21.7260
# Epoch 3/50
# 13/13 [==============================] - 0s 4ms/step - loss: 588.0575 - mae: 22.4231 - val_loss: 530.6157 - val_mae: 21.5826
# Epoch 4/50
# 13/13 [==============================] - 0s 4ms/step - loss: 581.2942 - mae: 22.2963 - val_loss: 525.0890 - val_mae: 21.4628
# Epoch 5/50
# 13/13 [==============================] - 0s 5ms/step - loss: 574.7365 - mae: 22.1631 - val_loss: 519.2729 - val_mae: 21.3303
# Epoch 6/50
# 13/13 [==============================] - 0s 4ms/step - loss: 567.0445 - mae: 21.9797 - val_loss: 512.3719 - val_mae: 21.1705
# Epoch 7/50
# 13/13 [==============================] - 0s 4ms/step - loss: 558.0382 - mae: 21.7447 - val_loss: 503.6045 - val_mae: 20.9636
# Epoch 8/50
# 13/13 [==============================] - 0s 4ms/step - loss: 547.1788 - mae: 21.4389 - val_loss: 493.3176 - val_mae: 20.7106
# Epoch 9/50
# 13/13 [==============================] - 0s 4ms/step - loss: 535.1413 - mae: 21.0866 - val_loss: 480.8150 - val_mae: 20.3876
# Epoch 10/50
# 13/13 [==============================] - 0s 4ms/step - loss: 520.8539 - mae: 20.6427 - val_loss: 465.7798 - val_mae: 19.9878
# Epoch 11/50
# 13/13 [==============================] - 0s 4ms/step - loss: 504.1247 - mae: 20.1387 - val_loss: 447.0904 - val_mae: 19.4851
# Epoch 12/50
# 13/13 [==============================] - 0s 4ms/step - loss: 484.8684 - mae: 19.6635 - val_loss: 424.8780 - val_mae: 18.8732
# Epoch 13/50
# 13/13 [==============================] - 0s 5ms/step - loss: 462.9182 - mae: 19.1649 - val_loss: 400.9627 - val_mae: 18.1966
# Epoch 14/50
# 13/13 [==============================] - 0s 4ms/step - loss: 439.8298 - mae: 18.6926 - val_loss: 374.0782 - val_mae: 17.4214
# Epoch 15/50
# 13/13 [==============================] - 0s 5ms/step - loss: 413.7960 - mae: 18.1568 - val_loss: 345.6267 - val_mae: 16.6212
# Epoch 16/50
# 13/13 [==============================] - 0s 4ms/step - loss: 386.1088 - mae: 17.5465 - val_loss: 315.7764 - val_mae: 15.7586
# Epoch 17/50
# 13/13 [==============================] - 0s 4ms/step - loss: 356.1953 - mae: 16.8115 - val_loss: 286.3485 - val_mae: 14.9047
# Epoch 18/50
# 13/13 [==============================] - 0s 4ms/step - loss: 325.0498 - mae: 15.9818 - val_loss: 257.2422 - val_mae: 13.9801
# Epoch 19/50
# 13/13 [==============================] - 0s 4ms/step - loss: 292.9284 - mae: 15.0494 - val_loss: 229.9252 - val_mae: 13.0201
# Epoch 20/50
# 13/13 [==============================] - 0s 4ms/step - loss: 261.9337 - mae: 14.0529 - val_loss: 204.0210 - val_mae: 12.2199
# Epoch 21/50
# 13/13 [==============================] - 0s 5ms/step - loss: 233.4670 - mae: 13.1154 - val_loss: 182.1213 - val_mae: 11.7219
# Epoch 22/50
# 13/13 [==============================] - 0s 4ms/step - loss: 208.0967 - mae: 12.2465 - val_loss: 163.4878 - val_mae: 11.1842
# Epoch 23/50
# 13/13 [==============================] - 0s 5ms/step - loss: 187.2153 - mae: 11.5337 - val_loss: 149.3992 - val_mae: 10.6709
# Epoch 24/50
# 13/13 [==============================] - 0s 4ms/step - loss: 169.4357 - mae: 10.8709 - val_loss: 138.3323 - val_mae: 10.2013
# Epoch 25/50
# 13/13 [==============================] - 0s 4ms/step - loss: 155.6398 - mae: 10.3641 - val_loss: 129.3627 - val_mae: 9.7641
# Epoch 26/50
# 13/13 [==============================] - 0s 4ms/step - loss: 144.1338 - mae: 9.8943 - val_loss: 121.5093 - val_mae: 9.3637
# Epoch 27/50
# 13/13 [==============================] - 0s 4ms/step - loss: 133.8684 - mae: 9.4569 - val_loss: 113.0723 - val_mae: 8.9947
# Epoch 28/50
# 13/13 [==============================] - 0s 4ms/step - loss: 124.0507 - mae: 9.0685 - val_loss: 105.3942 - val_mae: 8.6537
# Epoch 29/50
# 13/13 [==============================] - 0s 5ms/step - loss: 115.0512 - mae: 8.7246 - val_loss: 98.7401 - val_mae: 8.3428
# Epoch 30/50
# 13/13 [==============================] - 0s 4ms/step - loss: 106.4897 - mae: 8.3648 - val_loss: 92.0300 - val_mae: 8.0421
# Epoch 31/50
# 13/13 [==============================] - 0s 4ms/step - loss: 98.3108 - mae: 8.0248 - val_loss: 85.8476 - val_mae: 7.7293
# Epoch 32/50
# 13/13 [==============================] - 0s 5ms/step - loss: 90.7116 - mae: 7.6857 - val_loss: 80.1354 - val_mae: 7.4629
# Epoch 33/50
# 13/13 [==============================] - 0s 4ms/step - loss: 83.9654 - mae: 7.3799 - val_loss: 75.1194 - val_mae: 7.1892
# Epoch 34/50
# 13/13 [==============================] - 0s 4ms/step - loss: 77.6109 - mae: 7.0825 - val_loss: 70.4085 - val_mae: 6.9262
# Epoch 35/50
# 13/13 [==============================] - 0s 4ms/step - loss: 71.7402 - mae: 6.7761 - val_loss: 66.0331 - val_mae: 6.6726
# Epoch 36/50
# 13/13 [==============================] - 0s 5ms/step - loss: 66.3444 - mae: 6.4823 - val_loss: 62.0196 - val_mae: 6.4432
# Epoch 37/50
# 13/13 [==============================] - 0s 5ms/step - loss: 61.5677 - mae: 6.2164 - val_loss: 58.4280 - val_mae: 6.2400
# Epoch 38/50
# 13/13 [==============================] - 0s 4ms/step - loss: 57.2531 - mae: 5.9826 - val_loss: 54.9124 - val_mae: 6.0925
# Epoch 39/50
# 13/13 [==============================] - 0s 5ms/step - loss: 53.2375 - mae: 5.7355 - val_loss: 51.8976 - val_mae: 5.9055
# Epoch 40/50
# 13/13 [==============================] - 0s 4ms/step - loss: 49.5951 - mae: 5.5182 - val_loss: 49.1628 - val_mae: 5.7772
# Epoch 41/50
# 13/13 [==============================] - 0s 4ms/step - loss: 46.3191 - mae: 5.3091 - val_loss: 46.3349 - val_mae: 5.6228
# Epoch 42/50
# 13/13 [==============================] - 0s 4ms/step - loss: 43.3604 - mae: 5.1094 - val_loss: 44.2731 - val_mae: 5.5155
# Epoch 43/50
# 13/13 [==============================] - 0s 4ms/step - loss: 40.6046 - mae: 4.9286 - val_loss: 42.1913 - val_mae: 5.3884
# Epoch 44/50
# 13/13 [==============================] - 0s 5ms/step - loss: 38.0999 - mae: 4.7483 - val_loss: 40.1434 - val_mae: 5.2559
# Epoch 45/50
# 13/13 [==============================] - 0s 6ms/step - loss: 35.7304 - mae: 4.5870 - val_loss: 38.3596 - val_mae: 5.1387
# Epoch 46/50
# 13/13 [==============================] - 0s 5ms/step - loss: 33.7389 - mae: 4.4268 - val_loss: 36.6382 - val_mae: 4.9854
# Epoch 47/50
# 13/13 [==============================] - 0s 5ms/step - loss: 31.8568 - mae: 4.2817 - val_loss: 35.4064 - val_mae: 4.8861
# Epoch 48/50
# 13/13 [==============================] - 0s 5ms/step - loss: 30.1544 - mae: 4.1656 - val_loss: 34.0402 - val_mae: 4.7773
# Epoch 49/50
# 13/13 [==============================] - 0s 4ms/step - loss: 28.6357 - mae: 4.0369 - val_loss: 32.8515 - val_mae: 4.6695
# Epoch 50/50
# 13/13 [==============================] - 0s 5ms/step - loss: 27.3174 - mae: 3.9156 - val_loss: 31.7353 - val_mae: 4.5839

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)[['mae', 'val_mae']].plot(figsize=(10, 6))
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# #### Evaluación de los resultados

# %%
test_loss, test_mae = network.evaluate(X_test_prep, y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 33.9372 - mae: 4.2312

# %%
# Error absoluto medio
print('test_mae:', test_mae)
# Out:
# test_mae: 2.8056561946868896

# %% [markdown]
# #### Función de error de Huber

# %% [markdown]
# A continuación se muestra la representación gráfica de la evaluación de los valores resultantes de la función de error de **_huber_** durante el proceso de entrenamiento.

# %%
network = models.Sequential()

network.add(layers.Dense(30, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(10, activation='relu'))
network.add(layers.Dense(1))

# %%
network.compile(
    # Uso de la funcion Huber Loss
    loss=create_huber(1.0),
    optimizer='adam',
    metrics=['mae']
               )

# %%
history = network.fit(X_train_prep, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 13ms/step - loss: 21.8708 - mae: 22.3708 - val_loss: 20.8960 - val_mae: 21.3960
# Epoch 2/50
# 13/13 [==============================] - 0s 4ms/step - loss: 21.4168 - mae: 21.9168 - val_loss: 20.4458 - val_mae: 20.9458
# Epoch 3/50
# 13/13 [==============================] - 0s 4ms/step - loss: 20.9449 - mae: 21.4449 - val_loss: 19.9457 - val_mae: 20.4457
# Epoch 4/50
# 13/13 [==============================] - 0s 4ms/step - loss: 20.4202 - mae: 20.9199 - val_loss: 19.3623 - val_mae: 19.8623
# Epoch 5/50
# 13/13 [==============================] - 0s 4ms/step - loss: 19.8070 - mae: 20.3069 - val_loss: 18.6571 - val_mae: 19.1548
# Epoch 6/50
# 13/13 [==============================] - 0s 4ms/step - loss: 19.0719 - mae: 19.5694 - val_loss: 17.8202 - val_mae: 18.3200
# Epoch 7/50
# 13/13 [==============================] - 0s 4ms/step - loss: 18.2450 - mae: 18.7415 - val_loss: 16.8660 - val_mae: 17.3645
# Epoch 8/50
# 13/13 [==============================] - 0s 4ms/step - loss: 17.2608 - mae: 17.7582 - val_loss: 15.6817 - val_mae: 16.1751
# Epoch 9/50
# 13/13 [==============================] - 0s 5ms/step - loss: 16.0919 - mae: 16.5889 - val_loss: 14.3945 - val_mae: 14.8836
# Epoch 10/50
# 13/13 [==============================] - 0s 4ms/step - loss: 14.8257 - mae: 15.3221 - val_loss: 13.1318 - val_mae: 13.6174
# Epoch 11/50
# 13/13 [==============================] - 0s 5ms/step - loss: 13.5045 - mae: 14.0003 - val_loss: 12.1242 - val_mae: 12.6235
# Epoch 12/50
# 13/13 [==============================] - 0s 4ms/step - loss: 12.2048 - mae: 12.6981 - val_loss: 11.4679 - val_mae: 11.9679
# Epoch 13/50
# 13/13 [==============================] - 0s 4ms/step - loss: 11.2318 - mae: 11.7248 - val_loss: 10.7224 - val_mae: 11.2224
# Epoch 14/50
# 13/13 [==============================] - 0s 4ms/step - loss: 10.4037 - mae: 10.8925 - val_loss: 10.0525 - val_mae: 10.5477
# Epoch 15/50
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7841 - mae: 10.2746 - val_loss: 9.4996 - val_mae: 9.9983
# Epoch 16/50
# 13/13 [==============================] - 0s 4ms/step - loss: 9.2130 - mae: 9.7047 - val_loss: 8.9231 - val_mae: 9.4172
# Epoch 17/50
# 13/13 [==============================] - 0s 5ms/step - loss: 8.6105 - mae: 9.0983 - val_loss: 8.3488 - val_mae: 8.8149
# Epoch 18/50
# 13/13 [==============================] - 0s 5ms/step - loss: 7.9901 - mae: 8.4785 - val_loss: 7.7841 - val_mae: 8.2719
# Epoch 19/50
# 13/13 [==============================] - 0s 5ms/step - loss: 7.3600 - mae: 7.8478 - val_loss: 7.2017 - val_mae: 7.6958
# Epoch 20/50
# 13/13 [==============================] - 0s 5ms/step - loss: 6.7335 - mae: 7.2199 - val_loss: 6.5944 - val_mae: 7.0791
# Epoch 21/50
# 13/13 [==============================] - 0s 5ms/step - loss: 6.1242 - mae: 6.6110 - val_loss: 5.9939 - val_mae: 6.4815
# Epoch 22/50
# 13/13 [==============================] - 0s 4ms/step - loss: 5.5464 - mae: 6.0283 - val_loss: 5.3999 - val_mae: 5.8686
# Epoch 23/50
# 13/13 [==============================] - 0s 6ms/step - loss: 4.9961 - mae: 5.4773 - val_loss: 4.9142 - val_mae: 5.3720
# Epoch 24/50
# 13/13 [==============================] - 0s 4ms/step - loss: 4.5097 - mae: 4.9918 - val_loss: 4.5283 - val_mae: 4.9928
# Epoch 25/50
# 13/13 [==============================] - 0s 4ms/step - loss: 4.1150 - mae: 4.5929 - val_loss: 4.2374 - val_mae: 4.7129
# Epoch 26/50
# 13/13 [==============================] - 0s 4ms/step - loss: 3.7891 - mae: 4.2657 - val_loss: 3.9551 - val_mae: 4.4191
# Epoch 27/50
# 13/13 [==============================] - 0s 4ms/step - loss: 3.5409 - mae: 4.0190 - val_loss: 3.7817 - val_mae: 4.2613
# Epoch 28/50
# 13/13 [==============================] - 0s 4ms/step - loss: 3.3338 - mae: 3.8044 - val_loss: 3.6611 - val_mae: 4.1378
# Epoch 29/50
# 13/13 [==============================] - 0s 4ms/step - loss: 3.1476 - mae: 3.6136 - val_loss: 3.5468 - val_mae: 4.0090
# Epoch 30/50
# 13/13 [==============================] - 0s 5ms/step - loss: 3.0067 - mae: 3.4704 - val_loss: 3.4251 - val_mae: 3.8975
# Epoch 31/50
# 13/13 [==============================] - 0s 5ms/step - loss: 2.8543 - mae: 3.3163 - val_loss: 3.3579 - val_mae: 3.8333
# Epoch 32/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.7308 - mae: 3.1929 - val_loss: 3.2912 - val_mae: 3.7537
# Epoch 33/50
# 13/13 [==============================] - 0s 6ms/step - loss: 2.6201 - mae: 3.0746 - val_loss: 3.2085 - val_mae: 3.6800
# Epoch 34/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.5300 - mae: 2.9869 - val_loss: 3.1204 - val_mae: 3.5831
# Epoch 35/50
# 13/13 [==============================] - 0s 5ms/step - loss: 2.4279 - mae: 2.8834 - val_loss: 3.0926 - val_mae: 3.5569
# Epoch 36/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.3471 - mae: 2.7970 - val_loss: 3.0201 - val_mae: 3.4900
# Epoch 37/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.2759 - mae: 2.7267 - val_loss: 2.9814 - val_mae: 3.4551
# Epoch 38/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.2117 - mae: 2.6553 - val_loss: 2.9236 - val_mae: 3.4014
# Epoch 39/50
# 13/13 [==============================] - 0s 5ms/step - loss: 2.1563 - mae: 2.6017 - val_loss: 2.8643 - val_mae: 3.3431
# Epoch 40/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.1167 - mae: 2.5600 - val_loss: 2.8086 - val_mae: 3.2878
# Epoch 41/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.0833 - mae: 2.5241 - val_loss: 2.7785 - val_mae: 3.2561
# Epoch 42/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.0554 - mae: 2.5003 - val_loss: 2.7514 - val_mae: 3.2321
# Epoch 43/50
# 13/13 [==============================] - 0s 4ms/step - loss: 2.0229 - mae: 2.4675 - val_loss: 2.6837 - val_mae: 3.1570
# Epoch 44/50
# 13/13 [==============================] - 0s 4ms/step - loss: 1.9844 - mae: 2.4271 - val_loss: 2.6652 - val_mae: 3.1430
# Epoch 45/50
# 13/13 [==============================] - 0s 4ms/step - loss: 1.9648 - mae: 2.4081 - val_loss: 2.6206 - val_mae: 3.0913
# Epoch 46/50
# 13/13 [==============================] - 0s 4ms/step - loss: 1.9346 - mae: 2.3758 - val_loss: 2.5892 - val_mae: 3.0580
# Epoch 47/50
# 13/13 [==============================] - 0s 5ms/step - loss: 1.9136 - mae: 2.3543 - val_loss: 2.5689 - val_mae: 3.0350
# Epoch 48/50
# 13/13 [==============================] - 0s 6ms/step - loss: 1.8930 - mae: 2.3306 - val_loss: 2.5269 - val_mae: 2.9856
# Epoch 49/50
# 13/13 [==============================] - 0s 5ms/step - loss: 1.8688 - mae: 2.3083 - val_loss: 2.5106 - val_mae: 2.9702
# Epoch 50/50
# 13/13 [==============================] - 0s 4ms/step - loss: 1.8562 - mae: 2.2933 - val_loss: 2.4632 - val_mae: 2.9145

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)[['mae', 'val_mae']].plot(figsize=(10, 6))
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# #### Evaluación de los resultados

# %%
test_loss, test_mae = network.evaluate(X_test_prep, y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 2.3640 - mae: 2.8057

# %%
# Error absoluto medio
print('test_mae:', test_mae)
# Out:
# test_mae: 2.8056561946868896

# %% [markdown]
# ## Guardando el modelo en disco con objetos personalizados

# %% [markdown]
# Cuando nuestro modelo contiene algún componente personalizado, debemos realizar el siguiente procedimiento para almacenar el modelo en disco e importarlo cuando sea necesario

# %%
# Guardamos el modelo en disco
network.save("modelo_huber_loss.h5")

# %%
# Importamos el modelo previamente guardado en disco
network2 = tf.keras.models.load_model("modelo_huber_loss.h5",
                                      custom_objects={"huber_fn": create_huber(1.0)})

# %%
history = network2.fit(X_train_prep, 
                      y_train, 
                      epochs=2, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/2
# 13/13 [==============================] - 0s 13ms/step - loss: 1.8317 - mae: 2.2671 - val_loss: 2.4705 - val_mae: 2.9227
# Epoch 2/2
# 13/13 [==============================] - 0s 4ms/step - loss: 1.8225 - mae: 2.2620 - val_loss: 2.4486 - val_mae: 2.8964
